# %% [markdown]
# # ⚡ Apache Spark Installation & Verification on Cluster
#
# This guide demonstrates how to **install Spark**, **start Spark Shell**, and **verify the installation** using a sample dataset.
#
# ---
#
# ## 🛠️ Step 1: Install Apache Spark on Cluster
#
# ### Prerequisites
# - Java installed
# - Hadoop cluster (standalone or pseudo-distributed)
#
# ### Download & Extract Spark
# ```bash
# wget https://downloads.apache.org/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz
# tar -xvzf spark-3.5.0-bin-hadoop3.tgz
# ````
#
# ### Set Environment Variables
#
# ```bash
# export SPARK_HOME=~/spark-3.5.0-bin-hadoop3
# export PATH=$PATH:$SPARK_HOME/bin
# ```
#
# ---
#
# ## ▶️ Step 2: Start Spark Shell
#
# ```bash
# spark-shell
# ```
#
# ✔ Spark shell opens with Scala prompt (`scala>`)
#
# ---
#
# ## 📂 Step 3: Load a Sample Dataset
#
# Create a sample file `data.txt`:
#
# ```text
# apple
# banana
# apple
# orange
# banana
# ```
#
# Load data into Spark:
#
# ```scala
# val data = sc.textFile("data.txt")
# ```
#
# ---
#
# ## ✅ Step 4: Verify Basic Operations
#
# ### Count Records
#
# ```scala
# data.count()
# ```
#
# ### Word Count Operation
#
# ```scala
# data.map(word => (word,1)).reduceByKey(_+_).collect()
# ```
#
# ---
#
# ## 📊 Sample Output
#
# ```text
# (apple,2)
# (banana,2)
# (orange,1)
# ```
