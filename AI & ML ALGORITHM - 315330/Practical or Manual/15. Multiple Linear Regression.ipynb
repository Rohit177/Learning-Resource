# %% [markdown]
# # 🚀 **Practical No. 15: Implement Multiple Linear Regression Using Python**
#
# > 🎯 **Laboratory Learning Outcome (LLO) 15.1:**  Implement Multiple Linear Regression to model relationships between one dependent variable and multiple independent variables.
#
# > 📘 **Course Outcome (CO):** CO1
#
# > 💻 **Title:**  Write Program to Implement Multiple Linear Regression Using Python
#
# > 🌐 **Domain:** Artificial Intelligence and Machine Learning
#
# > 📚 **Subject:** AI & ML ALGORITHM
#
# > 🐍 **Language:** Python
#
# > 📖 **Description:**
# **Multiple Linear Regression** is a supervised machine learning algorithm used to predict a continuous output variable based on **two or more independent variables**. <br><br> 📊 It extends Simple Linear Regression by considering multiple features that influence the target variable.
# ---

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Import Dataset

# %%
url = 'https://raw.githubusercontent.com/kirenz/datasets/master/cars.csv'
df = pd.read_csv(url)
df.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration        Date Origin
# 0       130.0           3504          12.0  1970-01-01    USA
# 1       165.0           3693          11.5  1970-01-01    USA
# 2       150.0           3436          11.0  1970-01-01    USA
# 3       150.0           3433          12.0  1970-01-01    USA
# 4       140.0           3449          10.5  1970-01-01    USA

# %% [markdown]
# ### Plot data

# %%
plt.scatter(df['Miles_per_Gallon'],df['Horsepower'])

# %% [markdown]
# ### Define X and Y

# %%
X = df[['Miles_per_Gallon','Cylinders']]
Y = df['Horsepower']

# %% [markdown]
# > Shape of X and y

# %%
print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)
# Out:
# Shape of X: (392, 2)
# Shape of Y: (392,)

# %% [markdown]
# ### Split into train test
# > test size 20%

# %%
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.2)

# %% [markdown]
# > Shape of test train

# %%
print('x_train:', x_train.shape, 'y_train:', y_train.shape)
print('x_test: ', x_test.shape,  'y_test: ', y_test.shape)
# Out:
# x_train: (313, 1) y_train: (313,)
# x_test:  (79, 1) y_test:  (79,)

# %% [markdown]
# ### Define Algorithm

# %% [markdown]
# > Linear Regression

# %%
model = LinearRegression()

# %% [markdown]
# ### Fit algorithm

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predict result

# %%
model.predict(x_test)
# Out:
# array([115.51921245, 154.62980749,  76.4086174 ,  76.4086174 ,
#        115.51921245, 154.62980749,  76.4086174 ,  76.4086174 ,
#         76.4086174 , 154.62980749,  76.4086174 ,  76.4086174 ,
#        115.51921245,  76.4086174 , 115.51921245, 154.62980749,
#        115.51921245,  76.4086174 , 154.62980749,  76.4086174 ,
#         76.4086174 ,  76.4086174 , 115.51921245, 115.51921245,
#        115.51921245,  76.4086174 , 154.62980749, 115.51921245,
#        154.62980749, 154.62980749,  76.4086174 ,  76.4086174 ,
#         76.4086174 , 154.62980749, 154.62980749,  76.4086174 ,
#        115.51921245, 154.62980749,  76.4086174 , 154.62980749,
#        115.51921245, 154.62980749,  76.4086174 ,  76.4086174 ,
#         76.4086174 ,  76.4086174 ,  76.4086174 ,  76.4086174 ,
#         76.4086174 , 154.62980749,  76.4086174 , 154.62980749,
#         76.4086174 ,  76.4086174 ,  76.4086174 , 115.51921245,
#         76.4086174 , 154.62980749, 154.62980749,  76.4086174 ,
# ...

# %% [markdown]
# ### Check score

# %%
model.score(x_test,y_test)
# Out:
# 0.6548568450977288
