# %% [markdown]
# # 🚀 **Practical No. 02: Implement Breadth First Search (BFS) Algorithm (Uninformed) in Python**
#
# > 🎯 **Laboratory Learning Outcome (LLO) 2.1:**  Implement and analyze the Breadth First Search (BFS) algorithm for graph traversal and searching.
#
# > 📘 **Course Outcome (CO):** CO1
#
# > 💻 **Title:**  Write Program to Implement Breadth First Search (BFS) Algorithm (Uninformed) in Python
#
# > 🌐 **Domain:** Artificial Intelligence and Machine Learning
#
# > 📚 **Subject:** AI & ML ALGORITHM
#
# > 🐍 **Language:** Python
#
# > 📖 **Description:**
# **Breadth First Search (BFS)** is an **uninformed search algorithm** used for traversing or searching graph and tree data structures. <br><br>
# 🔍 BFS explores all neighboring nodes at the current depth level before moving to nodes at the next depth level. <br><br> 📊 It uses a **Queue (FIFO - First In First Out)** data structure to keep track of nodes to be visited.
#
# ---

# %%
graph = {
  '1' : [],
  '2' : [],
  '4' : ['5','6'],
  '5' : ['7'],
  '6' : ['1','2'],
  '7' : []
}

# Sample view as node of graph
#        4
#    5       6
# 7       1     2

visited = []   # List for visited nodes.
queue = []     # Initialize a queue

def bfs(visited, graph, node):  #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0)
    print (m, end = " ")

    for i in graph[m]:
      if i not in visited:
        visited.append(i)
        queue.append(i)

# Calling
print("Following is the Breadth-First Search")
bfs(visited, graph, '4')
# Out:
# Following is the Breadth-First Search
# 4 5 6 7 1 2
