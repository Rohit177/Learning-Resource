# %% [markdown]
# # 🚀 **Practical No. 01: Install Python IDE Software and Python “Scikit-Learn” for ML**
#
# > 🎯 **Laboratory Learning Outcome (LLO) 1.1:** Install the given IDE for Python.
#
# > 📘 **Course Outcome (CO):** CO1
#
# > 💻 **Title:**  Install Python IDE Software and Python “Scikit-Learn” for ML
#
# > 🌐 **Domain:** Artificial Intelligence and Machine Learning
#
# > 📚 **Subject:** AI & ML ALGORITHM
#
# > 🐍 **Language:** Python
#
# > 📖 **Description:**
# Python is a powerful and easy-to-learn programming language widely used in Data Science and Machine Learning.  <br><br>
# 📓 **Jupyter Notebook** provides an interactive environment to write and execute Python code.  <br><br>
# 🤖 **Scikit-Learn** is a Python library used for Machine Learning, Data Mining, and Data Analysis.
#
# ---
#
# ## 🛠️ Installation Commands
#
# ### Install Jupyter Notebook
# ```bash
# pip install notebook
# ```
#
# ### Install Scikit-Learn
# ```bash
# pip install scikit-learn
# ```
#
# ### Verify Installation
# ```python
# import sklearn
# print("Installed Successfully")
# ```
#
#
# ###Launch Jupyter Notebook
# ```python
# jupyter notebook
# or
# python -m notebook
# ```
#
# ---
#
# ## 📚 Resource
#
# 🔗 **Google Colab Cheat Sheet:**
# https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Cheat_sheet_for_Google_Colab.ipynb
#
# ---
#
# <div align="center">
#
# </div>
